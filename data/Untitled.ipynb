# %%
# %load_ext autoreload
# %autoreload 2

import main as m
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
R = 8.314 # J/K. mol

# %%
n = 10000
Ca = m.generate_values(2e3, 3e3, n)
Cb = m.generate_values(2e3, 3e3, n)
T = m.generate_values(50+273, 100+273, n)
Q = m.generate_values(8e-3, 8.5e-3, n)

data = pd.DataFrame()
data['Cae'] = Ca
data['Cbe'] = Cb
data['Cce'] = 0
data['Cde'] = 0
data['T'] = T
data['Q'] = Q
C = ['Cae', 'Cbe', 'Cce', 'Cde']

# %%
Ea = 83680
k0 = .26e11
V = 200e-3 # m³

data['k1'] = m.cte_taxa(T, k0, Ea, R)
data['k2'] = 0

# %%
out = m.ss_solve(data[C], data['k1'], data['k2'], data['Q'], V)

# %%
data.join(out)
# Out:
#               Cae          Cbe  Cce  Cde           T         Q        k1  k2  \
# 0     2553.900958  2829.790022    0    0  354.675967  0.008259  0.012320   0
# 1     2805.832662  2308.554094    0    0  349.020198  0.008125  0.007779   0
# 2     2559.295945  2334.294720    0    0  369.012405  0.008061  0.037105   0
# 3     2024.096161  2470.218882    0    0  367.106972  0.008334  0.032207   0
# 4     2031.581166  2671.095644    0    0  355.169781  0.008440  0.012816   0
# ...           ...          ...  ...  ...         ...       ...       ...  ..
# 9995  2240.338800  1982.539063    0    0  329.848259  0.008388  0.001455   0
# 9996  2440.695526  2341.516504    0    0  369.557219  0.008164  0.038627   0
# 9997  2261.137070  2454.076455    0    0  329.594856  0.008183  0.001422   0
# 9998  2638.653253  2313.310685    0    0  347.977076  0.008312  0.007134   0
# 9999  2796.063390  2031.490910    0    0  332.665411  0.008031  0.001884   0
#
# ...
